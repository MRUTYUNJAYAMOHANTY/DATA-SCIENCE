# %% [markdown]
# # conda install matplotlib or pip install matplotlib
#
#   https://matplotlib.org/

# %% [markdown]
# matplotlib offers 2D and 3D graphics library for generating scientific figures.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# need to use this line to see plots in the notebook:

# %%
# %matplotlib inline

# %% [markdown]
# The above line is only for jupyter notebooks, if you are using another editor, you'll use: plt.show() at the end of all your plotting commands to have the figure pop up in another window.

# %% [markdown]
# example using two numpy arrays:
# we can also use lists, but most likely we'll be passing numpy arrays or pandas columns (which essentially also behave like arrays).
#
# ** The data we want to plot:**

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# # Functional Plot

# %%
plt.plot(x,y,'r') # 'r' is the color red
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# # Creating Multiplots on Same Canvas

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x, y, 'r') # More on color options later
plt.subplot(1,2,2)
plt.plot(y, x, 'b');

# %% [markdown]
# # Matplotlib Object Oriented Method
#  This means we will instantiate figure objects and then call methods or attributes from that object.
#  create figure objects and then just call methods or attributes off of that object.Better approach dealing with a canvas that has multiple plots on it.

# %%
# Create Figure (empty canvas)
fig = plt.figure()

# Add set of axes to figure
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)
axes.plot(x,y)
axes.set_xlabel('X Label') # Notice the use of set_ to begin methods
axes.set_ylabel('y Label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# add more than one axis to the figure:

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes1')
axes1.set_ylabel('Y_label_axes1')
axes1.set_title('Axes 1 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %% [markdown]
# # subplots()
# The plt.subplots() object will act as a more automatic axis manager.

# %%
axes
# Out:
# <Axes:title={'center':'Title'}, xlabel='X Label', ylabel='y Label'>

# %%
# Use similar to plt.figure() except use tuple unpacking to grab fig and axes
fig, axes = plt.subplots(nrows=1,ncols=2)

# To fix overlaps
plt.tight_layout()

# for current_ax in axes:
#     current_ax.plot(x,y)


axes[0].plot(x, y)
axes[0].set_title('First plot')
axes[1].plot(y,x)
axes[1].set_title('Second plot')

# To fix overlaps
plt.tight_layout()

# %%
# Use similar to plt.figure() except use tuple unpacking to grab fig and axes
fig, axes = plt.subplots()

# Now use the axes object to add stuff to plot
axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %% [markdown]
# # Figure size, aspect ratio and DPI

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. It can use the figsize and dpi keyword arguments.
#
# figsize is a tuple of the width and height of the figure in inches
# dpi is the dots-per-inch (pixel per inch).
# For example:

# %%
fig = plt.figure(figsize=(3,2))
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_title('Title')
ax.set_ylabel('Y')
ax.set_xlabel('X')
# Out:
# Text(0.5, 0, 'X')

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %% [markdown]
# # Saving figures
# Matplotlib can generate high-quality output in a number formats, including PNG, JPG, EPS, SVG, PGF and PDF.

# %%
fig.savefig("filename.png",dpi=200)

# %% [markdown]
# # Legends, labels and titles

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label = 'X squared')
ax.plot(x,x**3, label = 'X cubed' )
ax.legend() # set position of legend
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html

# %% [markdown]
# # Plot Apperance

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color='#FF8C00',linewidth=2,alpha=0.5,linestyle='-',marker='o',
        markersize=20,markerfacecolor='yellow',markeredgewidth=3,markeredgecolor='green' ) # RGB Hexcode , aplpha for transperency , 
                                                                  # linewidth can be written as lw, linstyle as ls

# %% [markdown]
# # Control over axis apperance
# controlling axis sizing properties in a matplotlib figure.

# %% [markdown]
# # Plot Range
# We can configure the ranges of the axes using the set_ylim and set_xlim methods in the axis object, or axis('tight') for automatically getting "tightly fitted" axes ranges:

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color='red',lw=2,ls='--') 

#show plot between 0 and 1 x-axis
ax.set_xlim([0,1])
#show plot between 0 and 1 y-axis
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)

# %% [markdown]
# # Special plot type

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([ 7., 11.,  9., 11., 11.,  3., 14., 15., 10.,  9.]),
#  array([  2., 100., 198., 296., 394., 492., 590., 688., 786., 884., 982.]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);
